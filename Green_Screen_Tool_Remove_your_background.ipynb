# %% [markdown]
# <a href="https://colab.research.google.com/github/Abs-CV/Computer-Vision-Nanodegree-Excercise-Master/blob/main/Green_Screen_Tool_Remove_your_background.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Color Threshold, Green Screen

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image = mpimg.imread('images/car_green_screen.jpg')

# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)
# Out:
# Image dimensions: (450, 660, 3)

# %%
# Display the image
plt.imshow(image)

# %% [markdown]
# ### Define the color threshold

# %%
## TODO: Define our color selection boundaries in RGB values
lower_green = np.array([0,245,0]) 
upper_green = np.array([255,255,255])

# %% [markdown]
# ### Create a mask

# %%
# Define the masked area
mask = cv2.inRange(image, lower_green, upper_green)

# Vizualize the mask
plt.imshow(mask, cmap='gray')

# %%
# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %% [markdown]
# ### Mask and add a background image

# %%
# Load in a background image, and convert it to RGB 
background_image = mpimg.imread('images/sky.jpg')
background_image=cv2.resize(background_image,(660,450))


background_image[mask == 0] = [0, 0, 0]
plt.imshow(background_image)

# %% [markdown]
# ### Create a complete image

# %%
keep=background_image+masked_image
plt.imshow(keep)

# %%
mask.shape,background_image.shape
# Out:
# ((450, 660), (450, 660, 3))

# %%
mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
